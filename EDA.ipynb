# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.xls'))

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df['PhoneService'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df['MultipleLines'].unique()
# Out:
# array(['No phone service', 'No', 'Yes'], dtype=object)

# %%
df['NumberOfLines'] = np.where((df['MultipleLines']=='No phone service') | (df['MultipleLines']=='No'),'One','More than one')

# %%
df[['PhoneService','MultipleLines','NumberOfLines']].sample(5)
# Out:
#      PhoneService MultipleLines  NumberOfLines
# 3379          Yes            No            One
# 3158          Yes            No            One
# 2480          Yes           Yes  More than one
# 2444          Yes           Yes  More than one
# 5327          Yes            No            One

# %%
df['StreamingTV'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['StreamingMovies'].unique()
# Out:
# array(['No', 'Yes', 'No internet service'], dtype=object)

# %%
df['StreamingTVOrMovies'] = np.where((df['StreamingMovies'] == 'Yes') | (df['StreamingTV'] == 'Yes'),'Yes','No')

# %%
df[['StreamingTV','StreamingMovies','StreamingTVOrMovies']].sample(10)
# Out:
#               StreamingTV      StreamingMovies StreamingTVOrMovies
# 6269                   No                   No                  No
# 703   No internet service  No internet service                  No
# 5676  No internet service  No internet service                  No
# 2523  No internet service  No internet service                  No
# 6340                  Yes                   No                 Yes
# 4249                   No                  Yes                 Yes
# 5429                   No                  Yes                 Yes
# 2568  No internet service  No internet service                  No
# 1183                  Yes                  Yes                 Yes
# 5489                   No                   No                  No

# %%
df['StreamingTVOrMovies'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)
