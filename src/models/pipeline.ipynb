# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
import sys
import os

# Move up one directory level to the 'src' root folder
sys.path.append(os.path.abspath('..'))

# Import the specific function from your preprocess file

from data.preprocess import to_numeric,remove_space,encode_columns,fill_na
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[21], line 9
#       5 sys.path.append(os.path.abspath('..'))
#       7 # Import the specific function from your preprocess file
# ----> 9 from data.preprocess import to_numeric,remove_space,encode_columns,fill_na
#
# ImportError: cannot import name 'fill_na' from 'data.preprocess' (c:\Users\Dhvanish\OneDrive\Desktop\ML projects\Churn prediction\src\data\preprocess.py)

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.xls')

# %%
df = to_numeric(df)
df = remove_space(df)
df = encode_columns(df)

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.8,random_state=42)

# %%
df.isnull().sum()
# Out:
# customerID           0
# gender               0
# SeniorCitizen        0
# Partner              0
# Dependents           0
# tenure               0
# PhoneService         0
# MultipleLines        0
# InternetService      0
# OnlineSecurity       0
# OnlineBackup         0
# DeviceProtection     0
# TechSupport          0
# StreamingTV          0
# StreamingMovies      0
# Contract             0
# PaperlessBilling     0
# PaymentMethod        0
# MonthlyCharges       0
# TotalCharges        11
# Churn                0
# dtype: int64
