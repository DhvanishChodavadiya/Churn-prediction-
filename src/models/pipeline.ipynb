# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# %%
from src.data.preprocess import to_numeric,remove_space,encode_columns

# %%
df = pd.read_csv('WA_Fn-UseC_-Telco-Customer-Churn.xls')

# %%
df = to_numeric(df)
df = remove_space(df)
df = encode_columns(df)

# %%
X = df.drop(columns=['Churn'])
y = df['Churn']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.8,random_state=42)
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 6176  0475-RIJEP       1              0      No         No      43
# 3496  5201-FRKKS       1              0      No         No      25
# 2969  1163-VIPRI       0              0     Yes        Yes      65
# 90    4767-HZZHQ       1              0     Yes        Yes      30
# 4867  0899-LIIBW       1              0     Yes         No      34
#
#      PhoneService MultipleLines InternetService OnlineSecurity  ...  \
# 6176          Yes           Yes      Fiberoptic             No  ...
# 3496          Yes            No      Fiberoptic            Yes  ...
# 2969          Yes           Yes      Fiberoptic            Yes  ...
# 90            Yes            No      Fiberoptic             No  ...
# 4867          Yes           Yes      Fiberoptic             No  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies Contract  \
# 6176               No          No          No              No        0
# 3496               No          No          No              No        0
# 2969              Yes         Yes         Yes             Yes        2
# 90                Yes          No          No              No        0
# 4867              Yes          No         Yes             Yes        0
#
#       PaperlessBilling            PaymentMethod MonthlyCharges  TotalCharges  \
# 6176               Yes          Electroniccheck          77.85       3365.85
# 3496                No  Banktransfer(automatic)          74.30       1952.25
# 2969                No          Electroniccheck         109.30       7337.55
# 90                  No  Banktransfer(automatic)          82.05       2570.20
# 4867                No          Electroniccheck         100.85       3527.30
#
#       Churn
# 6176    Yes
# 3496     No
# 2969     No
# 90       No
# 4867     No
#
# [5 rows x 21 columns]
